# %% [markdown]
# # Catégorisez automatiquement des questions - Stack Overflow
#
# #### Objectif:
# Développement d'un système de suggestion de tags via une API pour facilité la recherche aux utilisateurs sur le site Stack Overflow. Celui-ci prendra la forme d’un algorithme de machine learning qui assignera automatiquement plusieurs tags pertinents à une question.
#
#
# Dans ce notebook:
# - Vectorisation
# - Entrainement des modèles
#
# ### Sommaire
#
# * [Import](#chapter1)
#     * [Librairies](#section_1_1)
#     * [Données](#section_1_2)
#
#
# * [Les fonctions](#chapter2)
#     * [Nettoyage](#section_2_1)
#     * [Vectorization](#section_2_2)
#     * [Représentation](#section_2_3)
#
#
# * [Vectorization](#chapter3)
#     * [Bag of Word & Tf idf](#section_3_1)
#     * [Word Embeddings](#section_3_2)
#         * [Word2Vect](#section_3_2_1)
#         * [Bert](#section_3_2_2)
#         * [USE](#section_3_2_3)
#
#
# * [Modélisation](#chapter4)
#     * [Non supervisée: Latent Dirichlet Allocation](#section_4_1)
#     * [Modélisation supervisée](#section_4_2)

# %% [markdown]
# ## Import <a class="anchor" id="chapter1"></a>
# ### Librairies <a class="anchor" id="section_1_1"></a>

# %%
# Import des librairies
import numpy as np
import pandas as pd
import re
import ast
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import pickle
import time
from bs4 import BeautifulSoup

# Tokenizer
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

from sklearn import cluster, metrics
from sklearn import manifold, decomposition
import logging

import gensim

logging.disable(logging.WARNING) # disable WARNING, INFO and DEBUG logging everywhere

# %%
import tensorflow

# %%
from tensorflow import *

# %%
#Word2Vec
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

import tensorflow_hub as hub

# %%
# Bert
import os
import transformers
from transformers import *

os.environ["TF_KERAS"]='1'

# %%
print(tf.__version__)
print(tensorflow.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# 2.9.1
# 2.9.1
# Num GPUs Available:  0
# False

# %%
#pip install tensorflow_hub
# Out:
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 221.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.12.0 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from tensorflow_hub) (1.22.3)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from tensorflow_hub) (3.20.1)
# Installing collected packages: tensorflow_hub
# Successfully installed tensorflow_hub-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Nos données <a class="anchor" id="section_1_2"></a>

# %%
data = pd.read_csv('processed_data.csv')

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.shape
# Out:
# (27977, 5)

# %%
data.head(1)
# Out:
#                                                 Body  \
# 0  <p>I want to assign the decimal variable &quot...
#
#                                                Tags  \
# 0  c#,floating-point,type-conversion,double,decimal
#
#                                                 Text  \
# 0  How to convert Decimal to Double in C#?<p>I wa...
#
#                                         Cleaned_text  length_cleaned_text  \
# 0  convert decimal double want assign decimal var...                   26
#
#    body_tokens_count top_tags
# 0                 26       c#

# %%
data["Tags"].count()
# Out:
# 24882

# %%
data["top_tags"].count()
# Out:
# 24882

# %% [markdown]
# ## Fonctions <a class="anchor" id="chapter2"></a>
# ### Nattoyages <a class="anchor" id="section_2_1"></a>

# %%
# Tokenizer
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

def remove_code(html):
    # parse html content
    soup = BeautifulSoup(html, "html.parser")  
    for data in soup(['style', 'script']):
        # Remove tags
        data.decompose()  
    # return data by retrieving the tag content
    return soup.stripped_strings

def regex(text):
    # Remove html tags
    text=re.sub(r"<[^>]*>",' ', str(text))
    # Remove usernames "@"
    text=re.sub(r'@\S+', ' ', text)
    # Remove hashtags
    text=re.sub(r'#\S+', ' ', text)
    # Remove punctuation
    text=re.sub(r'[^\w\s]', ' ', text)
    # Remove unicode characters
    text = text.encode("ascii", "ignore").decode()
    # Remove irrelevant characters
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    # Remove English contractions
    text = re.sub("\'\w+", '', text)
    # Remove extra spaces
    text = re.sub('\s+', ' ', text)
    # Remove whitespace
    text=re.sub(r'^\s*|\s\s*', ' ', text).strip()
    # Remove numbers
    text = re.sub(r'\w*\d+\w*', '', text)
    # Remove links
    text = re.sub(r'http*\S+', '', text)
    text=text.replace('\n', ' ')
    return text

def tokenizer_fct(sentence) :
    # print(sentence)
    sentence_clean = sentence.replace('-', ' ').replace('+', ' ').replace('/', ' ').replace('#', ' ')
    word_tokens = word_tokenize(sentence_clean)
    return word_tokens

# Stop words
from nltk.corpus import stopwords
stop_w = list(set(stopwords.words('english'))) + ['[', ']', ',', '.', ':', '?', '(', ')']

def stop_word_filter_fct(list_words) :
    filtered_w = [w for w in list_words if not w in stop_w]
    filtered_w2 = [w for w in filtered_w if len(w) > 2]
    return filtered_w2

# lower case et alpha
def lower_start_fct(list_words) :
    lw = [w.lower() for w in list_words if (not w.startswith("@")) 
    #                                   and (not w.startswith("#"))
                                       and (not w.startswith("http"))]
    return lw

# Lemmatizer (base d'un mot)
from nltk.stem import WordNetLemmatizer

def lemma_fct(list_words) :
    lemmatizer = WordNetLemmatizer()
    lem_w = [lemmatizer.lemmatize(w) for w in list_words]
    return lem_w

# %% [markdown]
# ### Préparation pour la vectorization <a class="anchor" id="section_2_2"></a>

# %%
# Fonction de preparation du text pour la vectorization bag of word, Tf idf et Word2Vec
def transform_bow_fct(desc_text) :
    lw = lower_start_fct(desc_text)
    text_regex = regex(lw)
    word_tokens = tokenizer_fct(text_regex)
    sw = stop_word_filter_fct(word_tokens)
    lem_w = lemma_fct(sw)
    transf_desc_text = ' '.join(lem_w)
    return transf_desc_text

# %%
# Fonction de préparation du texte pour le Deep learning (USE et BERT)
def transform_dl_fct(desc_text) :
    word_tokens = tokenizer_fct(desc_text)
    lw = lower_start_fct(word_tokens)
    transf_desc_text = ' '.join(lw)
    return transf_desc_text

# %% [markdown]
# ### Représentation graphique <a class="anchor" id="section_2_2"></a>

# %%
# Calcul Tsne, détermination des clusters et calcul ARI entre vrais catégorie et n° de clusters
def ARI_fct(features) :
    time1 = time.time()
    num_labels=len(l_cat)
    tsne = manifold.TSNE(n_components=2, perplexity=30, n_iter=2000, 
                                 init='random', learning_rate=200, random_state=42)
    X_tsne = tsne.fit_transform(features)
    
    # Détermination des clusters à partir des données après Tsne 
    cls = cluster.KMeans(n_clusters=num_labels, n_init=100, random_state=42)
    cls.fit(X_tsne)
    ARI = np.round(metrics.adjusted_rand_score(y_cat_num, cls.labels_),4)
    time2 = np.round(time.time() - time1,0)
    print("ARI : ", ARI, "time : ", time2)
    
    return ARI, X_tsne, cls.labels_


# visualisation du Tsne selon les vraies catégories et selon les clusters
def TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI) :
    fig = plt.figure(figsize=(15,6))
    
    ax = fig.add_subplot(121)
    scatter = ax.scatter(X_tsne[:,0],X_tsne[:,1], c=y_cat_num, cmap='Set1')
    ax.legend(handles=scatter.legend_elements()[0], labels=l_cat, loc="best", title="Categorie")
    plt.title('Représentation des questions par tags')
    
    ax = fig.add_subplot(122)
    scatter = ax.scatter(X_tsne[:,0],X_tsne[:,1], c=labels, cmap='Set1')
    ax.legend(handles=scatter.legend_elements()[0], labels=set(labels), loc="best", title="Clusters")
    plt.title('Représentation des questions par clusters')
    
    plt.show()
    print("ARI : ", ARI)

# %%
data['Cleaned_text'] = data['Cleaned_text'].astype("string")

# %%
data['Text'] = data['Text'].astype("string")

# %%
data['sentence_bow'] = data['Text'].apply(lambda x : transform_bow_fct(x))
data['sentence_dl'] = data['Text'].apply(lambda x : transform_dl_fct(x))
data.shape
# Out:
# (1245, 11)

# %%
print(data[data['length_dl']==11053]['sentence_dl'])
# Out:
# 48722    play with x , y , z coordinates < p > i have a...
# Name: sentence_dl, dtype: object

# %%
data[data['length_dl']==11053]
# Out:
#              Id         CreationDate  Score  ViewCount  AnswerCount  \
# 48722  16269727  2013-04-29 00:48:02      1        198            0
#
#        CommentCount  FavoriteCount    Tags  \
# 48722             5            1.0  python
#
#                                                     Text  \
# 48722  Play with x, y, z coordinates<p>I have a list ...
#
#                                             Cleaned_text  \
# 48722  play x z coordinate list list nlevels cloud po...
#
#                                             sentence_bow  \
# 48722  play coordinate list list nlevels cloud point ...
#
#                                              sentence_dl  length_bow  \
# 48722  play with x , y , z coordinates < p > i have a...         362
#
#        length_dl  length_text  length_cleaned_text
# 48722      11053        11003                  383

# %%
data['sentence_dl'][48722]
# Out:
# "play with x , y , z coordinates < p > i have a list of lists < code > nlevels < code > a 3d cloud of points : < p > < pre > < code > [ nodeid , x , y , z ] < code > < pre > < p > with multiple rows . some nodes will have the same < code > x < code > and < code > z < code > coordinates and different < code > y < code > coordinates. < p > < p > i 'd like to , first identify the different nodes with the same < code > x < code > and < code > z < code > coordinates and different < code > y < code > coordinates . < p > < p > then , using those < code > ( x , z ) < code > pairs and different < code > y < code > levels i 'd like to change the < code > x < code > coordinates of a second list ( < code > nodes < code > ) . < p > < p > the changes should respect the following : < p > < pre > < code > for x , y , z in ` nodes ` , if x=x , z=z and ( y level 1 & lt ; =y & lt ; y level 2 ) : change ` x ` coordinates between consecutive ` y ` levels , for each pair of ` ( x , z ) ` coordinates . additionally , the changes in ` x ` coordinates should depend on pairs of nodes with same ` ( x , y ) ` coordinates for different ` z ` levels . < code > < pre > < p > the idea behind this code is : for the nodes which have the same < code > x and y < code > change their values based on their < code > z < code > coordinates . this changes the vertical aligned nodes . these changes in < code > x and y < code > must now be propagated in the horizontally aligned nodes ( which have either the same < code > x and z < code > or the same < code > y and z < code > coordinates ) . < p > < p > because the changes in the horizontally aligned nodes depend on the changes in the vertical aligned nodes it is difficult for me to get the code working . i have to loop over the horizontal nodes and inside that loop , loop over the vertical nodes .... < p > < p > edit : solved . this code works ! < p > < pre > < code > nlevels= [ [ '173 ' , ' 0 . ' , ' 0 . ' , ' 0 . ' ] , [ '183 ' , '1000 . ' , ' 0 . ' , ' 0 . ' ] , [ '184 ' , ' 0 . ' , '1000 . ' , ' 0 . ' ] , [ '194 ' , '1000 . ' , '1000 . ' , ' 0 . ' ] , [ '195 ' , ' 0 . ' , ' 0 . ' , '1000 . ' ] , [ '205 ' , '1000 . ' , ' 0 . ' , '1000 . ' ] , [ '206 ' , ' 0 . ' , '1000 . ' , '1000 . ' ] , [ '216 ' , '1000 . ' , '1000 . ' , '1000 . ' ] , [ '217 ' , ' 0 . ' , ' 0 . ' , '2000 . ' ] , [ '227 ' , '1000 . ' , ' 0 . ' , '2000 . ' ] , [ '228 ' , ' 0 . ' , '1000 . ' , '2000 . ' ] , [ '238 ' , '1000 . ' , '1000 . ' , '2000 . ' ] , [ '239 ' , ' 0 . ' , ' 0 . ' , '3000 . ' ] , [ '249 ' , '1000 . ' , ' 0 . ' , '3000 . ' ] , [ '250 ' , ' 0 . ' , '1000 . ' , '3000 . ' ] , [ '260 ' , '1000 . ' , '1000 . ' , '3000 . ' ] , [ '261 ' , ' 0 . ' , ' 0 . ' , '4000 . ' ] , [ '271 ' , '1000 . ' , ' 0 . ' , '4000 . ' ] , [ '272 ' , ' 0 . ' , '1000 . ' , '4000 . ' ] , [ '282 ' , '1000 . ' , '1000 . ' , '4000 . ' ] , [ '283 ' , ' 0 . ' , ' 0 . ' , ' 0 . ' ] , [ '293 ' , ' 0 . ' , '1000 . ' , ' 0 . ' ] , [ '294 ' , '1000 . ' , ' 0 . ' , ' 0 . ' ] , [ '304 ' , '1000 . ' , '1000 . ' , ' 0 . ' ] , [ '305 ' , ' 0 . ' , ' 0 . ' , '1000 . ' ] , [ '315 ' , ' 0 . ' , '1000 . ' , '1000 . ' ] , [ '316 ' , '1000 . ' , ' 0 . ' , '1000 . ' ] , [ '326 ' , '1000 . ' , '1000 . ' , '1000 . ' ] , [ '327 ' , ' 0 . ' , ' 0 . ' , '2000 . ' ] , [ '337 ' , ' 0 . ' , '1000 . ' , '2000 . ' ] , [ '338 ' , '1000 . ' , ' 0 . ' , '2000 . ' ] , [ '348 ' , '1000 . ' , '1000 . ' , '2000 . ' ] , [ '349 ' , ' 0 . ' , ' 0 . ' , '3000 . ' ] , [ '359 ' , ' 0 . ' , '1000 . ' , '3000 . ' ] , [ '360 ' , '1000 . ' , ' 0 . ' , '3000 . ' ] , [ '370 ' , '1000 . ' , '1000 . ' , '3000 . ' ] , [ '371 ' , ' 0 . ' , ' 0 . ' , '4000 . ' ] , [ '381 ' , ' 0 . ' , '1000 . ' , '4000 . ' ] , [ '382 ' , '1000 . ' , ' 0 . ' , '4000 . ' ] , [ '392 ' , '1000 . ' , '1000 . ' , '4000 . ' ] , [ '436 ' , ' 1000 . ' , ' 0 . ' , ' 0 . ' ] , [ '446 ' , ' 0 . ' , ' 0 . ' , ' 0 . ' ] , [ '447 ' , ' 1000 . ' , '1000 . ' , ' 0 . ' ] , [ '457 ' , ' 0 . ' , '1000 . ' , ' 0 . ' ] , [ '458 ' , ' 1000 . ' , '1000 . ' , ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

data['length_bow'] = data['sentence_bow'].apply(lambda x : len(word_tokenize(x)))
max_length_bow = data['length_bow'].max()
print("max length bow : ", max_length_bow)

data['length_dl'] = data['sentence_dl'].apply(lambda x : len(word_tokenize(x)))
max_length_dl = data['length_dl'].max()
print("max length dl : ", max_length_dl)
# Out:
# max length bow :  0
# max length dl :  6369

# %%
data['length_text'] = data['Text'].apply(lambda x : len(word_tokenize(str(x))))
max_length_data_brute = data['length_text'].max()
print("max length Text : ", max_length_data_brute)
# Out:
# max length Text :  8053

# %%
data['length_cleaned_text'] = data['Cleaned_text'].apply(lambda x : len(word_tokenize(str(x))))
max_length_cleaned_data = data['length_cleaned_text'].max()
print("max length Cleaned_text : ", max_length_cleaned_data)
# Out:
# max length Cleaned_text :  3090

# %%
#def literal_return(val):
 #   try:
  #      return ast.literal_eval(val)
   # except ValueError:
    #    return (val)

#data['text_to_vect'] = data['Cleaned_text'].apply(literal_return)

# %%
#data['X']=data['text_to_vect'].apply(lambda x: ' '.join(x))

# %% [markdown]
# ## Vectorization <a class="anchor" id="chapter3"></a>
# ### Bag of word & Tf-idf <a class="anchor" id="section_3_1"></a>

# %%
data.head(2)
# Out:
#                                                 Body  \
# 0  <p>I'm working on a <strong>multithreaded</str...
# 1  <p>I'm currently writing an ASP.Net app from t...
#
#                                            Tags  \
# 0   c++,windows,multithreading,debugging,memory
# 1  c#,asp.net,exception,mvp,n-tier-architecture
#
#                                                 Text  \
# 0  Heap corruption under Win32; how to locate?<p>...
# 1  How Do You Communicate Service Layer Messages/...
#
#                               Tags_list  Tags_count  number_of_tags  \
# 0  ['c++', 'windows', 'multithreading']           5               3
# 1                     ['c#', 'asp.net']           5               2
#
#                                         Cleaned_text  body_tokens_count  \
# 0  heap corruption locate work multithreaded appl...                366
# 1  communicate service layer message error high l...                299
#
#    length_cleaned_text sentence_bow  \
# 0                  366
# 1                  299
#
#                                          sentence_dl  length_bow  length_dl  \
# 0  heap corruption under win32 ; how to locate ? ...           0       1172
# 1  how do you communicate service layer messages ...           0        827
#
#    length_text
# 0         1158
# 1          816

# %%
data['Tags_list'].value_counts()
# Out:
# ['android']                                 134
# ['java']                                     84
# ['python']                                   63
# ['c#']                                       57
# ['java', 'android']                          54
#                                            ...
# ['javascript', 'android', 'html', 'ios']      1
# ['php', 'arrays']                             1
# ['android', 'html']                           1
# ['c++', 'xcode', 'macos']                     1
# ['java', 'macos']                             1
# Name: Tags_list, Length: 297, dtype: int64

# %%
# Preparation des données:

X=data['sentence_bow']
y=data['Tags']

# %%
l_cat = list(set(data['Tags']))
print("catégories : ", l_cat)
y_cat_num = data["Tags"].nunique()
# Out:
# catégories :  ['vba', 'javascript', 'r', 'html', 'python']

# %%
data['Tags'].nunique()
# Out:
# 5

# %%
l_cat.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
y.value_counts()
# Out:
# javascript    24012
# python        15762
# r              5627
# html           4250
# vba             349
# Name: Tags, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

cvect = CountVectorizer(analyzer="word", stop_words='english', max_df=0.6, min_df=0.005)
ctf = TfidfVectorizer(analyzer="word", stop_words='english', max_df=0.6, min_df=0.005)


cv_fit = cvect.fit(X)
ctf_fit = ctf.fit(X)

X_BoW = cvect.transform(X)  
X_tfidf = ctf.transform(X)

# %%
print("Shape of X for Full_doc in BoW: {}".format(X_BoW.shape))
print("Shape of X for Full_doc in Tf-idf: {}".format(X_tfidf.shape))
# Out:
# Shape of X for Full_doc in BoW: (50000, 1072)
# Shape of X for Full_doc in Tf-idf: (50000, 1072)

# %% [markdown]
# Dans la suite nous allons travailler avec la vectorization Tf-idf

# %%
print("CountVectorizer : ")
print("-----------------")
ARI, X_tsne, labels = ARI_fct(X_BoW)
print()
print("Tf-idf : ")
print("--------")
ARI, X_tsne, labels = ARI_fct(X_tfidf)
# Out:
# CountVectorizer :
# -----------------
# ARI :  0.1631 time :  465.0
#
# Tf-idf :
# --------
# ARI :  0.096 time :  472.0

# %%
full_dense = X_tfidf.todense()
print("Full_doc sparsicity tf idf: {:.3f} %"\
      .format(((full_dense > 0).sum()/full_dense.size)*100))

# %%
print("CountVectorizer : ")
print("-----------------")
ARI, X_tsne, labels = ARI_fct(X_BoW)
print()
print("Tf-idf : ")
print("--------")
ARI, X_tsne, labels = ARI_fct(X_tfidf)
# Out:
# CountVectorizer :
# -----------------
# ARI :  0.072 time :  418.0
#
# Tf-idf :
# --------
# ARI :  0.1014 time :  431.0

# %%
 TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
# Out:
# ARI :  0.0986

# %%
# Multilabel binarizer for targets

from sklearn.preprocessing import MultiLabelBinarizer

multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(y)
y_binarized = multilabel_binarizer.transform(y)

print("Shape of y: {}".format(y_binarized.shape))
# Out:
# Shape of y: (50000, 16)

# %%
# Create train and test split (30%)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_binarized,
                                                    test_size=0.3, random_state=8)
print("X_train shape : {}".format(X_train.shape))
print("X_test shape : {}".format(X_test.shape))
print("y_train shape : {}".format(y_train.shape))
print("y_test shape : {}".format(y_test.shape))
# Out:
# X_train shape : (35000, 1072)
# X_test shape : (15000, 1072)
# y_train shape : (35000, 16)
# y_test shape : (15000, 16)

# %%
full_dense = X_tfidf.todense()
print("Full_doc sparsicity: {:.3f} %"\
      .format(((full_dense > 0).sum()/full_dense.size)*100))

# %% [markdown]
# Metriques :
# Accuracy score
# F1 score
# Jaccard similarity score
# Recall
# Precision

# %%
def metrics_score(model, df, y_true, y_pred):
    """Compilation function of metrics specific to multi-label
    classification problems in a Pandas DataFrame.
    This dataFrame will have 1 row per metric
    and 1 column per model tested. 

    Parameters
    ----------------------------------------
    model : string
        Name of the tested model
    df : DataFrame 
        DataFrame to extend. 
        If None : Create DataFrame.
    y_true : array
        Array of true values to test
    y_pred : array
        Array of predicted values to test
    ----------------------------------------
    """
    if(df is not None):
        temp_df = df
    else:
        temp_df = pd.DataFrame(index=["Accuracy", "F1",
                                      "Jaccard", "Recall",
                                      "Precision"],
                               columns=[model])
        
    scores = []
    scores.append(metrics.accuracy_score(y_true, 
                                         y_pred))
    scores.append(metrics.f1_score(y_pred, 
                                   y_true, 
                                   average='weighted'))
    scores.append(metrics.jaccard_score(y_true, 
                                        y_pred, 
                                        average='weighted'))
    scores.append(metrics.recall_score(y_true, 
                                       y_pred, 
                                       average='weighted'))
    scores.append(metrics.precision_score(y_true, 
                                          y_pred, 
                                          average='weighted'))
    temp_df[model] = scores
    
    return temp_df

# %% [markdown]
# ## Words Embeddings <a class="anchor" id="section_3_2"></a>

# %% [markdown]
# ### Word2Vec <a class="anchor" id="section_3_2_1"></a>

# %%
w2v_size=300
w2v_window=5
w2v_min_count=1
w2v_epochs=100
maxlen = max_length_bow # adapt to length of sentences

sentences = data['sentence_bow'].to_list()
sentences = [gensim.utils.simple_preprocess(text) for text in sentences]

# %%
# Création et entraînement du modèle Word2Vec

print("Build & train Word2Vec model ...")
w2v_model = gensim.models.Word2Vec(min_count=w2v_min_count, 
                                   window=w2v_window,
                                   vector_size=w2v_size,
                                   seed=42,
                                   workers=1)
# workers=multiprocessing.cpu_count())
w2v_model.build_vocab(sentences)
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=w2v_epochs)
model_vectors = w2v_model.wv
w2v_words = model_vectors.index_to_key
print("Vocabulary size: %i" % len(w2v_words))
print("Word2Vec trained")
# Out:
# Build & train Word2Vec model ...
# Vocabulary size: 106475
# Word2Vec trained

# %%
# Préparation des sentences (tokenization)

print("Fit Tokenizer ...")
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
x_sentences = pad_sequences(tokenizer.texts_to_sequences(sentences),
                                                     maxlen=maxlen,
                                                     padding='post') 
                                                   
num_words = len(tokenizer.word_index) + 1
print("Number of unique words: %i" % num_words)
# Out:
# Fit Tokenizer ...
# Number of unique words: 106476

# %%
# Création de la matrice d'embedding

print("Create Embedding matrix ...")
w2v_size = 300
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
embedding_matrix = np.zeros((vocab_size, w2v_size))
i=0
j=0
    
for word, idx in word_index.items():
    i +=1
    if word in w2v_words:
        j +=1
        embedding_vector = model_vectors[word]
        if embedding_vector is not None:
            embedding_matrix[idx] = model_vectors[word]
            
word_rate = np.round(j/i,4)
print("Word embedding rate : ", word_rate)
print("Embedding matrix: %s" % str(embedding_matrix.shape))
# Out:
# Create Embedding matrix ...
# Word embedding rate :  1.0
# Embedding matrix: (106476, 300)

# %%
# Création du modèle

input=Input(shape=(len(x_sentences),maxlen),dtype='float64')
word_input=Input(shape=(maxlen,),dtype='float64')  
word_embedding=Embedding(input_dim=vocab_size,
                         output_dim=w2v_size,
                         weights = [embedding_matrix],
                         input_length=maxlen)(word_input)

word_vec=GlobalAveragePooling1D()(word_embedding)  
embed_model = Model([word_input],word_vec)

embed_model.summary()
# Out:
# 2022-10-29 21:43:11.677968: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3496)]            0
#
#  embedding (Embedding)       (None, 3496, 300)         31942800
#
#  global_average_pooling1d (G  (None, 300)              0
#  lobalAveragePooling1D)
#
# =================================================================
# Total params: 31,942,800
# Trainable params: 31,942,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Exécution du modèle
embeddings = embed_model.predict(x_sentences)
embeddings.shape
# Out:
# 1563/1563 [==============================] - 59s 37ms/step
# (50000, 300)

# %%
ARI, X_tsne, labels = ARI_fct(embeddings)
# Out:
# ARI :  0.1483 time :  456.0

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
# Out:
# ARI :  0.1483

# %% [markdown]
# ### BERT <a class="anchor" id="section_3_2_2"></a>

# %% [markdown]
# #### Les Fonctions

# %%
# Fonction de préparation des sentences
def bert_inp_fct(sentences, bert_tokenizer, max_length) :
    input_ids=[]
    token_type_ids = []
    attention_mask=[]
    bert_inp_tot = []

    for sent in sentences:
        bert_inp = bert_tokenizer.encode_plus(sent,
                                              add_special_tokens = True,
                                              max_length = max_length,
                                              padding='max_length',
                                              return_attention_mask = True, 
                                              return_token_type_ids=True,
                                              truncation=True,
                                              return_tensors="tf")
    
        input_ids.append(bert_inp['input_ids'][0])
        token_type_ids.append(bert_inp['token_type_ids'][0])
        attention_mask.append(bert_inp['attention_mask'][0])
        bert_inp_tot.append((bert_inp['input_ids'][0], 
                             bert_inp['token_type_ids'][0], 
                             bert_inp['attention_mask'][0]))

    input_ids = np.asarray(input_ids)
    token_type_ids = np.asarray(token_type_ids)
    attention_mask = np.array(attention_mask)
    
    return input_ids, token_type_ids, attention_mask, bert_inp_tot
    

# Fonction de création des features
def feature_BERT_fct(model, model_type, sentences, max_length, b_size, mode='HF') :
    batch_size = b_size
    batch_size_pred = b_size
    bert_tokenizer = AutoTokenizer.from_pretrained(model_type)
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        input_ids, token_type_ids, attention_mask, bert_inp_tot = bert_inp_fct(sentences[idx:idx+batch_size], 
                                                                      bert_tokenizer, max_length)
        
        if mode=='HF' :    # Bert HuggingFace
            outputs = model.predict([input_ids, attention_mask, token_type_ids], batch_size=batch_size_pred)
            last_hidden_states = outputs.last_hidden_state

        if mode=='TFhub' : # Bert Tensorflow Hub
            text_preprocessed = {"input_word_ids" : input_ids, 
                                 "input_mask" : attention_mask, 
                                 "input_type_ids" : token_type_ids}
            outputs = model(text_preprocessed)
            last_hidden_states = outputs['sequence_output']
             
        if step ==0 :
            last_hidden_states_tot = last_hidden_states
            last_hidden_states_tot_0 = last_hidden_states
        else :
            last_hidden_states_tot = np.concatenate((last_hidden_states_tot,last_hidden_states))
    
    features_bert = np.array(last_hidden_states_tot).mean(axis=1)
    
    time2 = np.round(time.time() - time1,0)
    print("temps traitement : ", time2)
     
    return features_bert, last_hidden_states_tot

# %% [markdown]
# #### BERT HuggingFace

# %%
pip install --upgrade torch torchvision
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (1.10.2)
# Collecting torch
#   Downloading torch-1.13.0-cp39-none-macosx_10_9_x86_64.whl (137.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 MB 56.9 kB/s eta 0:00:0000:0102:41
# Collecting torchvision
#   Downloading torchvision-0.14.0-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.9 kB/s eta 0:00:0000:0100:02
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from torch) (4.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from torchvision) (1.22.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.2
#     Uninstalling torch-1.10.2:
#       Successfully uninstalled torch-1.10.2
# Successfully installed torch-1.13.0 torchvision-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
max_length = 64
batch_size = 10
model_type = 'bert-base-uncased'
model = TFAutoModel.from_pretrained(model_type,from_pt=True)
# Out:
# 2022-10-30 13:44:23.067631: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sentences = data['sentence_dl'].to_list()

# %%
# Création des features

features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences, 
                                                         max_length, batch_size, mode='HF')
# Out:
# Downloading: 100%|███████████████████████████| 28.0/28.0 [00:00<00:00, 10.0kB/s]
# Downloading: 100%|████████████████████████████| 226k/226k [00:00<00:00, 370kB/s]
# Downloading: 100%|████████████████████████████| 455k/455k [00:02<00:00, 176kB/s]
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 1s 919ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 916ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 839ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 874ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 909ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 906ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 916ms/step
# 1/1 [==============================] - 1s 914ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 916ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 928ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 930ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 993ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 993ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 952ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# ...
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 390s 390s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 3>()
#       1 # Création des features
# ----> 3 features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences,
#       4                                                          max_length, batch_size, mode='HF')
#
# Input In [37], in feature_BERT_fct(model, model_type, sentences, max_length, b_size, mode)
#      57         last_hidden_states_tot_0 = last_hidden_states
#      58     else :
# ---> 59         last_hidden_states_tot = np.concatenate((last_hidden_states_tot,last_hidden_states))
#      61 features_bert = np.array(last_hidden_states_tot).mean(axis=1)
#      63 time2 = np.round(time.time() - time1,0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
ARI, X_tsne, labels = ARI_fct(features_bert)

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)

# %% [markdown]
# ### Universal Sentence Encoder <a class="anchor" id="section_3_2_3"></a>

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
# Fonction

def feature_USE_fct(sentences, b_size) :
    batch_size = b_size
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        feat = embed(sentences[idx:idx+batch_size])

        if step ==0 :
            features = feat
        else :
            features = np.concatenate((features,feat))

    time2 = np.round(time.time() - time1,0)
    return features

# %%
batch_size = 10
sentences = data_T['sentence_dl'].to_list()

# %%
features_USE = feature_USE_fct(sentences, batch_size)

# %%
ARI, X_tsne, labels = ARI_fct(features_USE)

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)

# %%
pip install top2vec
# Out:
# Collecting top2vec
#   Downloading top2vec-1.0.27-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/lib/python3.9/site-packages (from top2vec) (1.20.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from top2vec) (1.3.4)
# Collecting hdbscan>=0.8.27
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 45 kB/s eta 0:00:014
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: wordcloud in /opt/anaconda3/lib/python3.9/site-packages (from top2vec) (1.8.2.2)
# Collecting umap-learn>=0.5.1
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 45 kB/s eta 0:00:01
# Collecting gensim>=4.0.0
#   Downloading gensim-4.2.0-cp39-cp39-macosx_10_9_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 86 kB/s eta 0:00:013
# Requirement already satisfied: smart-open>=1.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from gensim>=4.0.0->top2vec) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /opt/anaconda3/lib/python3.9/site-packages (from gensim>=4.0.0->top2vec) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.27->top2vec) (1.1.1)
# Requirement already satisfied: cython>=0.27 in /opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.27->top2vec) (0.29.24)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.27->top2vec) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.20->hdbscan>=0.8.27->top2vec) (2.2.0)
# Requirement already satisfied: numba>=0.49 in /opt/anaconda3/lib/python3.9/site-packages (from umap-learn>=0.5.1->top2vec) (0.54.1)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 217 kB/s eta 0:00:01
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from umap-learn>=0.5.1->top2vec) (4.62.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from numba>=0.49->umap-learn>=0.5.1->top2vec) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /opt/anaconda3/lib/python3.9/site-packages (from numba>=0.49->umap-learn>=0.5.1->top2vec) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->top2vec) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->top2vec) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->top2vec) (1.16.0)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.9/site-packages (from wordcloud->top2vec) (8.4.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from wordcloud->top2vec) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud->top2vec) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud->top2vec) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud->top2vec) (3.0.4)
# Building wheels for collected packages: hdbscan, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp39-cp39-macosx_10_9_x86_64.whl size=657730 sha256=9f8275bc81c88148750a0202153bcfb7c1c5815ed7c95091ad53da5d9a93f516
#   Stored in directory: /Users/Diana_1/Library/Caches/pip/wheels/97/2d/1e/d9907e8f806ee949f9effc41004d7f32e862f6f67d9157812d
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=5167e26f0c7ad0343cfce923e2a192c75c692fc30d0107ca5441bb4807dd55ba
#   Stored in directory: /Users/Diana_1/Library/Caches/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54287 sha256=5615047e4ce26a3b5b6398de003e5c413afcbfe157510eacf9c203176a06b674
#   Stored in directory: /Users/Diana_1/Library/Caches/pip/wheels/5b/f5/6e/aac11d69fe2115d9ac871d6c148b361f0d3f8a35ed7354fa03
# Successfully built hdbscan umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn, hdbscan, gensim, top2vec
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.8.3
#     Uninstalling gensim-3.8.3:
#       Successfully uninstalled gensim-3.8.3
# Successfully installed gensim-4.2.0 hdbscan-0.8.28 pynndescent-0.5.7 top2vec-1.0.27 umap-learn-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.8.0-py3-none-any.whl
# Out:
# Collecting tensorflow==1.8.0
#   Downloading https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.8.0-py3-none-any.whl (46.5 MB)
#      |████████████████████████████████| 46.5 MB 488 kB/s eta 0:00:01
# Collecting tensorboard<1.9.0,>=1.8.0
#   Downloading tensorboard-1.8.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 98 kB/s eta 0:00:011
# Collecting gast>=0.2.0
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow==1.8.0) (1.20.3)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow==1.8.0) (1.16.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow==1.8.0) (1.42.0)
# Collecting absl-py>=0.1.6
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: protobuf>=3.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow==1.8.0) (3.19.1)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow==1.8.0) (0.37.0)
# Collecting bleach==1.5.0
#   Downloading bleach-1.5.0-py2.py3-none-any.whl (17 kB)
# Collecting html5lib==0.9999999
#   Downloading html5lib-0.9999999.tar.gz (889 kB)
#      |████████████████████████████████| 889 kB 773 kB/s eta 0:00:01
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.10 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow==1.8.0) (2.0.2)
# Building wheels for collected packages: html5lib
#   Building wheel for html5lib (setup.py) ... done
#   Created wheel for html5lib: filename=html5lib-0.9999999-py3-none-any.whl size=107233 sha256=d8e2b64a40a49fa370ce81dbfcf87e6096b078250057373acaa5857736274aff
#   Stored in directory: /Users/Diana_1/Library/Caches/pip/wheels/f5/09/3f/ff7233827f32dd8856574fd464fdc480892ecc575c6ce62145
# Successfully built html5lib
# Installing collected packages: html5lib, bleach, termcolor, tensorboard, gast, astor, absl-py, tensorflow
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.1
#     Uninstalling html5lib-1.1:
#       Successfully uninstalled html5lib-1.1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 4.0.0
#     Uninstalling bleach-4.0.0:
#       Successfully uninstalled bleach-4.0.0
# Successfully installed absl-py-1.3.0 astor-0.8.1 bleach-1.5.0 gast-0.5.3 html5lib-0.9999999 tensorboard-1.8.0 tensorflow-1.8.0 termcolor-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### USE <a class="anchor" id="section_3_2_3"></a>

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
def feature_USE_fct(sentences, b_size) :
    batch_size = b_size
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        feat = embed(sentences[idx:idx+batch_size])

        if step ==0 :
            features = feat
        else :
            features = np.concatenate((features,feat))

    time2 = np.round(time.time() - time1,0)
    return features

# %%
batch_size = 10
sentences = data['sentence_dl'].to_list()

# %%
features_USE = feature_USE_fct(sentences, batch_size)

# %%
ARI, X_tsne, labels = ARI_fct(features_USE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 ARI, X_tsne, labels = ARI_fct(features_USE)
#
# Input In [22], in ARI_fct(features)
#      10 cls = cluster.KMeans(n_clusters=num_labels, n_init=100, random_state=42)
#      11 cls.fit(X_tsne)
# ---> 12 ARI = np.round(metrics.adjusted_rand_score(y_cat_num, cls.labels_),4)
#      13 time2 = np.round(time.time() - time1,0)
#      14 print("ARI : ", ARI, "time : ", time2)
#
# File /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:390, in adjusted_rand_score(labels_true, labels_pred)
#     309 def adjusted_rand_score(labels_true, labels_pred):
#     310     """Rand index adjusted for chance.
#     311
#     312     The Rand Index computes a similarity measure between two clusterings
#    (...)
#     388     adjusted_mutual_info_score : Adjusted Mutual Information.
#     389     """
# --> 390     (tn, fp), (fn, tp) = pair_confusion_matrix(labels_true, labels_pred)
#     391     # convert to Python integer types, to avoid overflow or underflow
#     392     tn, fp, fn, tp = int(tn), int(fp), int(fn), int(tp)
#
# File /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:221, in pair_confusion_matrix(labels_true, labels_pred)
#     161 def pair_confusion_matrix(labels_true, labels_pred):
#     162     """Pair confusion matrix arising from two clusterings [1]_.
#     163
#     164     The pair confusion matrix :math:`C` computes a 2 by 2 similarity matrix
#    (...)
#     219     Note that the matrix is not symmetric.
#     220     """
# --> 221     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     222     n_samples = np.int64(labels_true.shape[0])
#     224     # Computation using the contingency data
#
# File /opt/anaconda3/envs/Projet5/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:68, in check_clusterings(labels_true, labels_pred)
#      66 # input checks
#      67 if labels_true.ndim != 1:
# ---> 68     raise ValueError("labels_true must be 1D: shape is %r" % (labels_true.shape,))
#      69 if labels_pred.ndim != 1:
#      70     raise ValueError("labels_pred must be 1D: shape is %r" % (labels_pred.shape,))
#
# ValueError: labels_true must be 1D: shape is ()

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)

# %% [markdown]
# ## Modélisation <a class="anchor" id="chapter4"></a>
# ### Non-supervisée: Latent Dirichlet Allocation <a class="anchor" id="section_4_1"></a>

# %% [markdown]
# #### Prétraitement

# %%
# Create dictionnary (bag of words)
id2word = corpora.Dictionary(X)
id2word.filter_extremes(no_below=4, no_above=0.6, keep_n=None)
# Create Corpus 
texts = X  
# Term Document Frequency 
corpus = [id2word.doc2bow(text) for text in texts]  
# View 
print(corpus[:1])

# %%
# Création du modèle LDA
from sklearn.decomposition import LatentDirichletAllocation
n_topics = 20

# Créer le modèle LDA
lda = LatentDirichletAllocation(
        n_components=n_topics, 
        max_iter=5, 
        learning_method='online', 
        learning_offset=50.,
        random_state=0)

# Fitter sur les données
lda.fit(data[''])

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic {}:".format(topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, tf_feature_names, no_top_words)

# %% [markdown]
# ### Supervisée <a class="anchor" id="section_4_2"></a>
